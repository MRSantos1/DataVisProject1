# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing CSV to select random movies from 2015 and 2016
movie_data = "movie_metadata.csv"
movie_data = pd.read_csv('movie_metadata.csv')
pd.set_option('display.max_columns', 30)

movie_data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
# dropping NaN 
movie_data_na = movie_data.dropna()

movie_data_na
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
movie_data_na = movie_data_na.reset_index()


movie_data_na
# Out:
#       index  color      director_name  num_critic_for_reviews  duration  \
# 0         0  Color      James Cameron                   723.0     178.0
# 1         1  Color     Gore Verbinski                   302.0     169.0
# 2         2  Color         Sam Mendes                   602.0     148.0
# 3         3  Color  Christopher Nolan                   813.0     164.0
# 4         5  Color     Andrew Stanton                   462.0     132.0
# ...     ...    ...                ...                     ...       ...
# 3751   5026  Color    Olivier Assayas                    81.0     110.0
# 3752   5027  Color       Jafar Panahi                    64.0      90.0
# 3753   5033  Color      Shane Carruth                   143.0      77.0
# 3754   5035  Color   Robert Rodriguez                    56.0      81.0
# 3755   5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# ...

# %%
#resetting columns to only show movie titles and release year

movie_data_na = movie_data_na.loc[:,["movie_title" , "title_year" , "movie_facebook_likes"]]

movie_data_na
# Out:
#                                     movie_title  title_year  \
# 0                                       Avatar       2009.0
# 1     Pirates of the Caribbean: At World's End       2007.0
# 2                                      Spectre       2015.0
# 3                        The Dark Knight Rises       2012.0
# 4                                  John Carter       2012.0
# ...                                         ...         ...
# 3751                                     Clean       2004.0
# 3752                                The Circle       2000.0
# 3753                                    Primer       2004.0
# 3754                               El Mariachi       1992.0
# 3755                         My Date with Drew       2004.0
#
#       movie_facebook_likes
# 0                    33000
# 1                        0
# 2                    85000
# 3                   164000
# 4                    24000
# ...                    ...
# 3751                   171
# ...

# %%
#Renaming columns to remove underscores and remove decimal points
movie_data_titles_year = movie_data_na.rename(columns={"movie_title" : "Title",
                                                 "title_year" : "Release Year",
                                                  "movie_facebook_likes" : "Facebook Likes"     
                                                })


movie_data_titles_year
# Out:
#                                           Title  Release Year  Facebook Likes
# 0                                       Avatar         2009.0           33000
# 1     Pirates of the Caribbean: At World's End         2007.0               0
# 2                                      Spectre         2015.0           85000
# 3                        The Dark Knight Rises         2012.0          164000
# 4                                  John Carter         2012.0           24000
# ...                                         ...           ...             ...
# 3751                                     Clean         2004.0             171
# 3752                                The Circle         2000.0             697
# 3753                                    Primer         2004.0           19000
# 3754                               El Mariachi         1992.0               0
# 3755                         My Date with Drew         2004.0             456
#
# [3756 rows x 3 columns]

# %%
#Selecting movies from 2015 and 2016 and reset column
movies_2015 = movie_data_titles_year.loc[(movie_data_titles_year['Release Year'] == 2015.0)]
movies_2015.head()
# Out:
#                        Title  Release Year  Facebook Likes
# 2                   Spectre         2015.0           85000
# 7   Avengers: Age of Ultron         2015.0          118000
# 28           Jurassic World         2015.0          150000
# 44                Furious 7         2015.0           94000
# 60        Jupiter Ascending         2015.0           44000

# %%
movies_2016 = movie_data_titles_year.loc[(movie_data_titles_year['Release Year'] == 2016.0)]
movies_2016.head()
# Out:
#                                   Title  Release Year  Facebook Likes
# 9   Batman v Superman: Dawn of Justice         2016.0          197000
# 26          Captain America: Civil War         2016.0           72000
# 55                    Star Trek Beyond         2016.0           30000
# 61                The Legend of Tarzan         2016.0           29000
# 63                   X-Men: Apocalypse         2016.0           54000

# %%
#selecting random movies from 2015/2016 list
movie_rand_2015 = movies_2015.sample(n=10)
movie_rand_2015
# Out:
#                     Title  Release Year  Facebook Likes
# 1824              Legend         2015.0           43000
# 2727       Woman in Gold         2015.0           34000
# 2568          Ex Machina         2015.0          109000
# 659              Everest         2015.0           40000
# 123   Mad Max: Fury Road         2015.0          191000
# 3173            The Gift         2015.0           15000
# 3607    Creative Control         2015.0             793
# 3494      Brotherly Love         2015.0            1000
# 44             Furious 7         2015.0           94000
# 2811            The Gift         2015.0           15000

# %%
#selecting random movies from 2016 list
movie_rand_2016 = movies_2016.sample(n=10)
movie_rand_2016
# Out:
#                        Title  Release Year  Facebook Likes
# 2550   Miracles from Heaven         2016.0           16000
# 366        Now You See Me 2         2016.0           15000
# 172                 The BFG         2016.0           27000
# 2039                  Risen         2016.0           21000
# 1902        Eddie the Eagle         2016.0           15000
# 1297       How to Be Single         2016.0           15000
# 55         Star Trek Beyond         2016.0           30000
# 103                Warcraft         2016.0           89000
# 540   The Angry Birds Movie         2016.0           14000
# 975             Zoolander 2         2016.0           28000

# %%
#merging lists
merged_movie_list = pd.merge(movie_rand_2015, movie_rand_2016,  how="outer")
merged_movie_list.round()
# Out:
#                      Title  Release Year  Facebook Likes
# 0                  Legend         2015.0           43000
# 1           Woman in Gold         2015.0           34000
# 2              Ex Machina         2015.0          109000
# 3                 Everest         2015.0           40000
# 4      Mad Max: Fury Road         2015.0          191000
# 5                The Gift         2015.0           15000
# 6                The Gift         2015.0           15000
# 7        Creative Control         2015.0             793
# 8          Brotherly Love         2015.0            1000
# 9               Furious 7         2015.0           94000
# 10   Miracles from Heaven         2016.0           16000
# 11       Now You See Me 2         2016.0           15000
# 12                The BFG         2016.0           27000
# 13                  Risen         2016.0           21000
# 14        Eddie the Eagle         2016.0           15000
# ...

# %%
#Use YouTube API to retreive view count for trailers in list
confirmed_movie_list = ["Legend", "Woman in Gold" , "Ex Machina" , "Everest" , "Mad Max: Fury Road" , 
                       "The Longest Ride" , "Fantastic Four" , "Creed" , "Southpaw" , "Black Mass" , "London Has Fallen",
                       "Lights Out" , "The Young Messiah" , "Miracles from Heaven" , "Risen" , 
                       "The BFG" , "Dirty Grandpa" , "The 5th Wave" , "The Neon Demon" , "Ghostbusters"]

query_url = "https://www.googleapis.com/youtube/v3/activities"


titles = []
viewCount = []

for title in confirmed_movie_list:
    target_url = query_url + title

   # response = requests.get(target_url).json()
   # titles.append(response[0]['name'])
    #ratings.append(response[0]['statistics']['viewCount'])
    
    response = requests.get(query_url)
# Out:
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>
# <Response [400]>

# %%
#Use IMDB API to pull Rotten Tomatoes, IMDB, and Metacritic ratings

# %%
##############

# %%
# Create a scatter plot which compares Youtube Trailer Viewcount to Metacritic Rating
youtube_metacritic.plot(kind="scatter", x="youtube_viewcount", y="metacritic_rating", grid=True, figsize=(8,8),
              title="Youtube Viewcount vs. Metacritic Rating")
plt.show()

# %%
# Plot youtube Viewcount vs. Metacritic Rating as a line chart
youtube_vs_metacritic, = plt.plot(youtube_viewcount, metacritic_rating, color="blue", label="Metacritic_ViewCount_Correlation" )


# Create a legend for our chart
plt.legend(handles=[count_vs_metacritic], loc="best")

# Show the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2df14a18989d> in <module>
#       1 # Plot youtube Viewcount vs. Metacritic Rating as a line chart
# ----> 2 youtube_vs_metacritic, = plt.plot(youtube_viewcount, metacritic_rating, color="blue", label="Metacritic_ViewCount_Correlation" )
#       3
#       4
#       5 # Create a legend for our chart
#
# NameError: name 'plt' is not defined

# %%
# Create a scatter plot which compares Youtube Trailer Viewcount to Rotten Tomatoes Rating
youtube_rottentomato.plot(kind="scatter", x="youtube_viewcount", y="rottentomato_rating", grid=True, figsize=(8,8),
              title="Youtube Viewcount vs. Rotten Tomato Rating")
plt.show()

# %%
# Plot youtube Viewcount vs. Rotten Tomatoes Rating as a line chart
youtube_vs_rottentomato, = plt.plot(youtube_viewcount, rotten_tomato_rating, color="red", label="RottenTomato_ViewCount_Correlation" )


# Create a legend for our chart
plt.legend(handles=[youtube_vs_rottentomato], loc="best")

# Show the chart
plt.show()

# %%
# Create a scatter plot which compares Youtube Trailer Viewcount to IMDB Rating
youtube_IMDB.plot(kind="scatter", x="youtube_viewcount", y="IMDB_rating", grid=True, figsize=(8,8),
              title="Youtube Viewcount vs. IMDB Rating")
plt.show()

# %%
# Plot youtube Viewcount vs. IMDB Rating as a line chart
youtube_vs_IMDB, = plt.plot(youtube_viewcount, IMDB_rating, color="green", label="IMDB_ViewCount_Correlation" )


# Create a legend for our chart
plt.legend(handles=[youtube_vs_IMDB], loc="best")

# Show the chart
plt.show()
