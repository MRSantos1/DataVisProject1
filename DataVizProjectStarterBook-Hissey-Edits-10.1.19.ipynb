# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing CSV to select random movies from 2015 and 2016
movie_data = "movie_metadata.csv"
movie_data = pd.read_csv('movie_metadata.csv')
pd.set_option('display.max_columns', 30)

movie_data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name                                        movie_title  \
# 0      CCH Pounder                                            Avatar
# 1      Johnny Depp          Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                           Spectre
# 3        Tom Hardy                             The Dark Knight Rises
# 4      Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4                8                        143                   NaN
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   0.0                                                NaN
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...                   NaN
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4      NaN     NaN            NaN          NaN         NaN
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                    12.0         7.1           NaN                     0

# %%
# dropping NaN 
movie_data_na = movie_data.dropna()

movie_data_na
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 1                       563.0                  1000.0      Orlando Bloom
# 2                         0.0                   161.0       Rory Kinnear
# 3                     22000.0                 23000.0     Christian Bale
# 5                       475.0                   530.0    Samantha Morton
# ...                       ...                     ...                ...
# 5026                    107.0                    45.0     Béatrice Dalle
# 5027                    397.0                     0.0  Nargess Mamizadeh
# 5033                    291.0                     8.0     David Sullivan
# 5035                      0.0                     6.0    Peter Marquardt
# 5042                     16.0                    16.0   Brian Herzlinger
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# 1                    40000.0  309404152.0
# 2                    11000.0  200074175.0
# 3                    27000.0  448130642.0
# 5                      640.0   73058679.0
# ...                      ...          ...
# 5026                   576.0     136007.0
# 5027                     5.0     673780.0
# 5033                   291.0     424760.0
# 5035                   121.0    2040920.0
# 5042                    86.0      85222.0
#
#                                    genres             actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi              CCH Pounder
# 1                Action|Adventure|Fantasy              Johnny Depp
# 2               Action|Adventure|Thriller          Christoph Waltz
# 3                         Action|Thriller                Tom Hardy
# 5                 Action|Adventure|Sci-Fi             Daryl Sabara
# ...                                   ...                      ...
# 5026                  Drama|Music|Romance            Maggie Cheung
# 5027                                Drama  Fereshteh Sadre Orafaiy
# 5033                Drama|Sci-Fi|Thriller            Shane Carruth
# 5035  Action|Crime|Drama|Romance|Thriller          Carlos Gallardo
# 5042                          Documentary              John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# 2                                      Spectre            275868
# 3                        The Dark Knight Rises           1144337
# 5                                  John Carter            212204
# ...                                         ...              ...
# 5026                                     Clean              3924
# 5027                                The Circle              4555
# 5033                                    Primer             72639
# 5035                               El Mariachi             52055
# 5042                         My Date with Drew              4285
#
#       cast_total_facebook_likes          actor_3_name  facenumber_in_poster  \
# 0                          4834             Wes Studi                   0.0
# 1                         48350        Jack Davenport                   0.0
# 2                         11700      Stephanie Sigman                   1.0
# 3                        106759  Joseph Gordon-Levitt                   0.0
# 5                          1873          Polly Walker                   1.0
# ...                         ...                   ...                   ...
# 5026                        776          Don McKellar                   1.0
# 5027                          5      Mojgan Faramarzi                   0.0
# 5033                        368          Casey Gooden                   0.0
# 5035                        147        Consuelo Gómez                   0.0
# 5042                        163              Jon Gunn                   0.0
#
#                                           plot_keywords  \
# 0                avatar|future|marine|native|paraplegic
# 1     goddess|marriage ceremony|marriage proposal|pi...
# 2                   bomb|espionage|sequel|spy|terrorist
# 3     deception|imprisonment|lawlessness|police offi...
# 5     alien|american civil war|male nipple|mars|prin...
# ...                                                 ...
# 5026                     jail|junkie|money|motel|singer
# 5027          abortion|bus|hospital|prison|prostitution
# 5033  changing the future|independent film|invention...
# 5035                 assassin|death|guitar|gun|mariachi
# 5042  actress name in title|crush|date|four word tit...
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 5     http://www.imdb.com/title/tt0401729/?ref_=fn_t...                 738.0
# ...                                                 ...                   ...
# 5026  http://www.imdb.com/title/tt0388838/?ref_=fn_t...                  39.0
# 5027  http://www.imdb.com/title/tt0255094/?ref_=fn_t...                  26.0
# 5033  http://www.imdb.com/title/tt0390384/?ref_=fn_t...                 371.0
# 5035  http://www.imdb.com/title/tt0104815/?ref_=fn_t...                 130.0
# 5042  http://www.imdb.com/title/tt0378407/?ref_=fn_t...                  84.0
#
#      language country content_rating       budget  title_year  \
# 0     English     USA          PG-13  237000000.0      2009.0
# 1     English     USA          PG-13  300000000.0      2007.0
# 2     English      UK          PG-13  245000000.0      2015.0
# 3     English     USA          PG-13  250000000.0      2012.0
# 5     English     USA          PG-13  263700000.0      2012.0
# ...       ...     ...            ...          ...         ...
# 5026   French  France              R       4500.0      2004.0
# 5027  Persian    Iran      Not Rated      10000.0      2000.0
# 5033  English     USA          PG-13       7000.0      2004.0
# 5035  Spanish     USA              R       7000.0      1992.0
# 5042  English     USA             PG       1100.0      2004.0
#
#       actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                      936.0         7.9          1.78                 33000
# 1                     5000.0         7.1          2.35                     0
# 2                      393.0         6.8          2.35                 85000
# 3                    23000.0         8.5          2.35                164000
# 5                      632.0         6.6          2.35                 24000
# ...                      ...         ...           ...                   ...
# 5026                   133.0         6.9          2.35                   171
# 5027                     0.0         7.5          1.85                   697
# 5033                    45.0         7.0          1.85                 19000
# 5035                    20.0         6.9          1.37                     0
# 5042                    23.0         6.6          1.85                   456
#
# [3756 rows x 28 columns]

# %%
movie_data_na = movie_data_na.reset_index()


movie_data_na
# Out:
#       index  color      director_name  num_critic_for_reviews  duration  \
# 0         0  Color      James Cameron                   723.0     178.0
# 1         1  Color     Gore Verbinski                   302.0     169.0
# 2         2  Color         Sam Mendes                   602.0     148.0
# 3         3  Color  Christopher Nolan                   813.0     164.0
# 4         5  Color     Andrew Stanton                   462.0     132.0
# ...     ...    ...                ...                     ...       ...
# 3751   5026  Color    Olivier Assayas                    81.0     110.0
# 3752   5027  Color       Jafar Panahi                    64.0      90.0
# 3753   5033  Color      Shane Carruth                   143.0      77.0
# 3754   5035  Color   Robert Rodriguez                    56.0      81.0
# 3755   5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 1                       563.0                  1000.0      Orlando Bloom
# 2                         0.0                   161.0       Rory Kinnear
# 3                     22000.0                 23000.0     Christian Bale
# 4                       475.0                   530.0    Samantha Morton
# ...                       ...                     ...                ...
# 3751                    107.0                    45.0     Béatrice Dalle
# 3752                    397.0                     0.0  Nargess Mamizadeh
# 3753                    291.0                     8.0     David Sullivan
# 3754                      0.0                     6.0    Peter Marquardt
# 3755                     16.0                    16.0   Brian Herzlinger
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# 1                    40000.0  309404152.0
# 2                    11000.0  200074175.0
# 3                    27000.0  448130642.0
# 4                      640.0   73058679.0
# ...                      ...          ...
# 3751                   576.0     136007.0
# 3752                     5.0     673780.0
# 3753                   291.0     424760.0
# 3754                   121.0    2040920.0
# 3755                    86.0      85222.0
#
#                                    genres             actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi              CCH Pounder
# 1                Action|Adventure|Fantasy              Johnny Depp
# 2               Action|Adventure|Thriller          Christoph Waltz
# 3                         Action|Thriller                Tom Hardy
# 4                 Action|Adventure|Sci-Fi             Daryl Sabara
# ...                                   ...                      ...
# 3751                  Drama|Music|Romance            Maggie Cheung
# 3752                                Drama  Fereshteh Sadre Orafaiy
# 3753                Drama|Sci-Fi|Thriller            Shane Carruth
# 3754  Action|Crime|Drama|Romance|Thriller          Carlos Gallardo
# 3755                          Documentary              John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# 2                                      Spectre            275868
# 3                        The Dark Knight Rises           1144337
# 4                                  John Carter            212204
# ...                                         ...              ...
# 3751                                     Clean              3924
# 3752                                The Circle              4555
# 3753                                    Primer             72639
# 3754                               El Mariachi             52055
# 3755                         My Date with Drew              4285
#
#       cast_total_facebook_likes          actor_3_name  facenumber_in_poster  \
# 0                          4834             Wes Studi                   0.0
# 1                         48350        Jack Davenport                   0.0
# 2                         11700      Stephanie Sigman                   1.0
# 3                        106759  Joseph Gordon-Levitt                   0.0
# 4                          1873          Polly Walker                   1.0
# ...                         ...                   ...                   ...
# 3751                        776          Don McKellar                   1.0
# 3752                          5      Mojgan Faramarzi                   0.0
# 3753                        368          Casey Gooden                   0.0
# 3754                        147        Consuelo Gómez                   0.0
# 3755                        163              Jon Gunn                   0.0
#
#                                           plot_keywords  \
# 0                avatar|future|marine|native|paraplegic
# 1     goddess|marriage ceremony|marriage proposal|pi...
# 2                   bomb|espionage|sequel|spy|terrorist
# 3     deception|imprisonment|lawlessness|police offi...
# 4     alien|american civil war|male nipple|mars|prin...
# ...                                                 ...
# 3751                     jail|junkie|money|motel|singer
# 3752          abortion|bus|hospital|prison|prostitution
# 3753  changing the future|independent film|invention...
# 3754                 assassin|death|guitar|gun|mariachi
# 3755  actress name in title|crush|date|four word tit...
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4     http://www.imdb.com/title/tt0401729/?ref_=fn_t...                 738.0
# ...                                                 ...                   ...
# 3751  http://www.imdb.com/title/tt0388838/?ref_=fn_t...                  39.0
# 3752  http://www.imdb.com/title/tt0255094/?ref_=fn_t...                  26.0
# 3753  http://www.imdb.com/title/tt0390384/?ref_=fn_t...                 371.0
# 3754  http://www.imdb.com/title/tt0104815/?ref_=fn_t...                 130.0
# 3755  http://www.imdb.com/title/tt0378407/?ref_=fn_t...                  84.0
#
#      language country content_rating       budget  title_year  \
# 0     English     USA          PG-13  237000000.0      2009.0
# 1     English     USA          PG-13  300000000.0      2007.0
# 2     English      UK          PG-13  245000000.0      2015.0
# 3     English     USA          PG-13  250000000.0      2012.0
# 4     English     USA          PG-13  263700000.0      2012.0
# ...       ...     ...            ...          ...         ...
# 3751   French  France              R       4500.0      2004.0
# 3752  Persian    Iran      Not Rated      10000.0      2000.0
# 3753  English     USA          PG-13       7000.0      2004.0
# 3754  Spanish     USA              R       7000.0      1992.0
# 3755  English     USA             PG       1100.0      2004.0
#
#       actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                      936.0         7.9          1.78                 33000
# 1                     5000.0         7.1          2.35                     0
# 2                      393.0         6.8          2.35                 85000
# 3                    23000.0         8.5          2.35                164000
# 4                      632.0         6.6          2.35                 24000
# ...                      ...         ...           ...                   ...
# 3751                   133.0         6.9          2.35                   171
# 3752                     0.0         7.5          1.85                   697
# 3753                    45.0         7.0          1.85                 19000
# 3754                    20.0         6.9          1.37                     0
# 3755                    23.0         6.6          1.85                   456
#
# [3756 rows x 29 columns]

# %%
#resetting columns to only show movie titles and release year

movie_data_na = movie_data_na.loc[:,["movie_title" , "title_year" , "movie_facebook_likes"]]

movie_data_na
# Out:
#                                     movie_title  title_year  \
# 0                                       Avatar       2009.0
# 1     Pirates of the Caribbean: At World's End       2007.0
# 2                                      Spectre       2015.0
# 3                        The Dark Knight Rises       2012.0
# 4                                  John Carter       2012.0
# ...                                         ...         ...
# 3751                                     Clean       2004.0
# 3752                                The Circle       2000.0
# 3753                                    Primer       2004.0
# 3754                               El Mariachi       1992.0
# 3755                         My Date with Drew       2004.0
#
#       movie_facebook_likes
# 0                    33000
# 1                        0
# 2                    85000
# 3                   164000
# 4                    24000
# ...                    ...
# 3751                   171
# 3752                   697
# 3753                 19000
# 3754                     0
# 3755                   456
#
# [3756 rows x 3 columns]

# %%
#Renaming columns to remove underscores and remove decimal points
movie_data_titles_year = movie_data_na.rename(columns={"movie_title" : "Title",
                                                 "title_year" : "Release Year",
                                                  "movie_facebook_likes" : "Facebook Likes"     
                                                })


movie_data_titles_year
# Out:
#                                           Title  Release Year  Facebook Likes
# 0                                       Avatar         2009.0           33000
# 1     Pirates of the Caribbean: At World's End         2007.0               0
# 2                                      Spectre         2015.0           85000
# 3                        The Dark Knight Rises         2012.0          164000
# 4                                  John Carter         2012.0           24000
# ...                                         ...           ...             ...
# 3751                                     Clean         2004.0             171
# 3752                                The Circle         2000.0             697
# 3753                                    Primer         2004.0           19000
# 3754                               El Mariachi         1992.0               0
# 3755                         My Date with Drew         2004.0             456
#
# [3756 rows x 3 columns]

# %%
#Selecting movies from 2015 and 2016 and reset column
movies_2015 = movie_data_titles_year.loc[(movie_data_titles_year['Release Year'] == 2015.0)]
movies_2015.head()
# Out:
#                        Title  Release Year  Facebook Likes
# 2                   Spectre         2015.0           85000
# 7   Avengers: Age of Ultron         2015.0          118000
# 28           Jurassic World         2015.0          150000
# 44                Furious 7         2015.0           94000
# 60        Jupiter Ascending         2015.0           44000

# %%
movies_2016 = movie_data_titles_year.loc[(movie_data_titles_year['Release Year'] == 2016.0)]
movies_2016.head()
# Out:
#                                   Title  Release Year  Facebook Likes
# 9   Batman v Superman: Dawn of Justice         2016.0          197000
# 26          Captain America: Civil War         2016.0           72000
# 55                    Star Trek Beyond         2016.0           30000
# 61                The Legend of Tarzan         2016.0           29000
# 63                   X-Men: Apocalypse         2016.0           54000

# %%
#selecting random movies from 2015 list
movie_rand_2015 = movies_2015.sample(n=10, random_state=3)
movie_rand_2015
# Out:
#                     Title  Release Year  Facebook Likes
# 641                Focus         2015.0           23000
# 104   Terminator Genisys         2015.0           82000
# 3266                 Pan         2015.0           24000
# 606                Ted 2         2015.0           30000
# 76            Inside Out         2015.0          118000
# 775           Goosebumps         2015.0           35000
# 2386               Aloha         2015.0           11000
# 3401          Cinderella         2015.0           56000
# 1731           Self/less         2015.0           11000
# 1318            Ip Man 3         2015.0           12000

# %%
#selecting random movies from 2016 list
movie_rand_2016 = movies_2016.sample(n=10,random_state=24)
movie_rand_2016
# Out:
#                             Title  Release Year  Facebook Likes
# 919                     13 Hours         2016.0           44000
# 1483                Ghostbusters         2016.0           62000
# 2194  My Big Fat Greek Wedding 2         2016.0           19000
# 158                Gods of Egypt         2016.0           24000
# 1902             Eddie the Eagle         2016.0           15000
# 55              Star Trek Beyond         2016.0           30000
# 726            London Has Fallen         2016.0           28000
# 1288                The 5th Wave         2016.0           14000
# 71                 Suicide Squad         2016.0           80000
# 2010               Me Before You         2016.0           51000

# %%
#merging lists
merged_movie_list = pd.merge(movie_rand_2015, movie_rand_2016,  how="outer")
merged_movie_list.round()
confirmed_movie_list = [title.replace('\xa0','') for title in list(merged_movie_list['Title'])]
confirmed_movie_list
# Out:
# ['Focus',
#  'Terminator Genisys',
#  'Pan',
#  'Ted 2',
#  'Inside Out',
#  'Goosebumps',
#  'Aloha',
#  'Cinderella',
#  'Self/less',
#  'Ip Man 3',
#  '13 Hours',
#  'Ghostbusters',
#  'My Big Fat Greek Wedding 2',
#  'Gods of Egypt',
#  'Eddie the Eagle',
#  'Star Trek Beyond',
#  'London Has Fallen',
#  'The 5th Wave',
#  'Suicide Squad',
#  'Me Before You']

# %%
#titles_test =  #["Focus", "Termintor Genisys" , "Pan" , "Ted 2" , "Inside Out" , 
                       #"Goosebumps" , "Aloha" , "Cinderella" , "Self/less" , "Ip Man 3" , "13 Hours",
                       #"Ghostbusters" , "My Big Fat Greek Wedding 2" , "Gods of Egypt" , "Eddie the Eagle" , 
                       #56,48]

query_url =  "http://www.omdbapi.com/?apikey=e0ca3f65&t="


titles = []
viewCount = []

for title in confirmed_movie_list:
    title2 = title.replace(" ","+")
    target_url = query_url + title2
    
    
    response = requests.get(target_url).json()
    ratings = response['Ratings'] # because response is a dict
    print(title)
    for rating in ratings: # ratomgs is a list
        print(rating)
        #rating is a dictionay
        for key,value in rating.items():
            print(f'key: {key}, value: {value}')
    print("---------------------------------------------")
    #titles.append(response[0]['name'])
    #ratings.append(response[0]['statistics']['viewCount'])
    #print(ratings)
# Out:
# Focus
# {'Source': 'Internet Movie Database', 'Value': '6.6/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.6/10
# {'Source': 'Rotten Tomatoes', 'Value': '56%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 56%
# {'Source': 'Metacritic', 'Value': '56/100'}
# key: Source, value: Metacritic
# key: Value, value: 56/100
# ---------------------------------------------
# Terminator Genisys
# {'Source': 'Internet Movie Database', 'Value': '6.4/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.4/10
# {'Source': 'Rotten Tomatoes', 'Value': '26%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 26%
# {'Source': 'Metacritic', 'Value': '38/100'}
# key: Source, value: Metacritic
# key: Value, value: 38/100
# ---------------------------------------------
# Pan
# {'Source': 'Internet Movie Database', 'Value': '5.7/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 5.7/10
# {'Source': 'Rotten Tomatoes', 'Value': '27%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 27%
# {'Source': 'Metacritic', 'Value': '36/100'}
# key: Source, value: Metacritic
# key: Value, value: 36/100
# ---------------------------------------------
# Ted 2
# {'Source': 'Internet Movie Database', 'Value': '6.3/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.3/10
# {'Source': 'Rotten Tomatoes', 'Value': '45%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 45%
# {'Source': 'Metacritic', 'Value': '48/100'}
# key: Source, value: Metacritic
# key: Value, value: 48/100
# ---------------------------------------------
# Inside Out
# {'Source': 'Internet Movie Database', 'Value': '8.2/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 8.2/10
# {'Source': 'Rotten Tomatoes', 'Value': '98%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 98%
# {'Source': 'Metacritic', 'Value': '94/100'}
# key: Source, value: Metacritic
# key: Value, value: 94/100
# ---------------------------------------------
# Goosebumps
# {'Source': 'Internet Movie Database', 'Value': '6.3/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.3/10
# {'Source': 'Rotten Tomatoes', 'Value': '78%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 78%
# {'Source': 'Metacritic', 'Value': '60/100'}
# key: Source, value: Metacritic
# key: Value, value: 60/100
# ---------------------------------------------
# Aloha
# {'Source': 'Internet Movie Database', 'Value': '5.4/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 5.4/10
# {'Source': 'Rotten Tomatoes', 'Value': '20%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 20%
# {'Source': 'Metacritic', 'Value': '40/100'}
# key: Source, value: Metacritic
# key: Value, value: 40/100
# ---------------------------------------------
# Cinderella
# {'Source': 'Internet Movie Database', 'Value': '6.9/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.9/10
# {'Source': 'Rotten Tomatoes', 'Value': '85%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 85%
# {'Source': 'Metacritic', 'Value': '67/100'}
# key: Source, value: Metacritic
# key: Value, value: 67/100
# ---------------------------------------------
# Self/less
# {'Source': 'Internet Movie Database', 'Value': '6.5/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.5/10
# {'Source': 'Rotten Tomatoes', 'Value': '19%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 19%
# {'Source': 'Metacritic', 'Value': '34/100'}
# key: Source, value: Metacritic
# key: Value, value: 34/100
# ---------------------------------------------
# Ip Man 3
# {'Source': 'Internet Movie Database', 'Value': '7.1/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 7.1/10
# {'Source': 'Metacritic', 'Value': '57/100'}
# key: Source, value: Metacritic
# key: Value, value: 57/100
# ---------------------------------------------
# 13 Hours
# {'Source': 'Internet Movie Database', 'Value': '7.3/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 7.3/10
# {'Source': 'Rotten Tomatoes', 'Value': '51%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 51%
# {'Source': 'Metacritic', 'Value': '48/100'}
# key: Source, value: Metacritic
# key: Value, value: 48/100
# ---------------------------------------------
# Ghostbusters
# {'Source': 'Internet Movie Database', 'Value': '7.8/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 7.8/10
# {'Source': 'Rotten Tomatoes', 'Value': '97%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 97%
# {'Source': 'Metacritic', 'Value': '71/100'}
# key: Source, value: Metacritic
# key: Value, value: 71/100
# ---------------------------------------------
# My Big Fat Greek Wedding 2
# {'Source': 'Internet Movie Database', 'Value': '6.0/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.0/10
# {'Source': 'Rotten Tomatoes', 'Value': '28%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 28%
# {'Source': 'Metacritic', 'Value': '37/100'}
# key: Source, value: Metacritic
# key: Value, value: 37/100
# ---------------------------------------------
# Gods of Egypt
# {'Source': 'Internet Movie Database', 'Value': '5.4/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 5.4/10
# {'Source': 'Rotten Tomatoes', 'Value': '16%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 16%
# {'Source': 'Metacritic', 'Value': '25/100'}
# key: Source, value: Metacritic
# key: Value, value: 25/100
# ---------------------------------------------
# Eddie the Eagle
# {'Source': 'Internet Movie Database', 'Value': '7.4/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 7.4/10
# {'Source': 'Rotten Tomatoes', 'Value': '82%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 82%
# {'Source': 'Metacritic', 'Value': '54/100'}
# key: Source, value: Metacritic
# key: Value, value: 54/100
# ---------------------------------------------
# Star Trek Beyond
# {'Source': 'Internet Movie Database', 'Value': '7.1/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 7.1/10
# {'Source': 'Rotten Tomatoes', 'Value': '86%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 86%
# {'Source': 'Metacritic', 'Value': '68/100'}
# key: Source, value: Metacritic
# key: Value, value: 68/100
# ---------------------------------------------
# London Has Fallen
# {'Source': 'Internet Movie Database', 'Value': '5.9/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 5.9/10
# {'Source': 'Rotten Tomatoes', 'Value': '26%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 26%
# {'Source': 'Metacritic', 'Value': '28/100'}
# key: Source, value: Metacritic
# key: Value, value: 28/100
# ---------------------------------------------
# The 5th Wave
# {'Source': 'Internet Movie Database', 'Value': '5.2/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 5.2/10
# {'Source': 'Rotten Tomatoes', 'Value': '15%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 15%
# {'Source': 'Metacritic', 'Value': '33/100'}
# key: Source, value: Metacritic
# key: Value, value: 33/100
# ---------------------------------------------
# Suicide Squad
# {'Source': 'Internet Movie Database', 'Value': '6.0/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 6.0/10
# {'Source': 'Rotten Tomatoes', 'Value': '27%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 27%
# {'Source': 'Metacritic', 'Value': '40/100'}
# key: Source, value: Metacritic
# key: Value, value: 40/100
# ---------------------------------------------
# Me Before You
# {'Source': 'Internet Movie Database', 'Value': '7.4/10'}
# key: Source, value: Internet Movie Database
# key: Value, value: 7.4/10
# {'Source': 'Rotten Tomatoes', 'Value': '55%'}
# key: Source, value: Rotten Tomatoes
# key: Value, value: 55%
# {'Source': 'Metacritic', 'Value': '51/100'}
# key: Source, value: Metacritic
# key: Value, value: 51/100
# ---------------------------------------------

# %%
# Import Dependencies
import pandas as pd

# %%
# Creating dataframe of movie and ratings

# Initialize data of lists based on previous data extraction
movie_data = {'Movie Name' : ['Focus', 'Termintor Genisys', 'Pan', 'Ted 2', 'Inside Out',
'Goosebumps', 'Aloha', 'Cinderella', 'Self/less', 'Ip Man 3', '13 Hours',
'Ghostbusters', 'My Big Fat Greek Wedding 2', 'Gods of Egypt', 'Eddie the Eagle',
'Star Trek Beyond', 'London Has Fallen', 'The 5th Wave', 'Suicide Squad', 'Me Before You'],
'IMDB Rating' : [66, 64, 57, 63, 82, 63, 54, 69, 65, 71, 73, 78, 60, 54, 74, 71, 59, 52, 60, 74],
'Rotten Tomatoes Rating' : [56, 26, 27, 45, 98, 78, 20, 85, 19, 78, 51, 97, 28, 16, 82, 86, 26, 15, 27, 55],
'Metacritic Rating' : [56, 38, 36, 48, 94, 60, 40, 67, 34, 57, 48, 71, 37, 25, 54, 68, 28, 33, 40, 51],
'Facebook Likes' : [23000, 82000, 24000, 30000, 118000, 35000, 11000, 56000, 11000, 12000, 44000, 62000, 19000, 24000, 15000, 30000, 28000, 14000, 80000, 51000]}

# %%
# Create the DataFrame
master_movie_df = pd.DataFrame(movie_data)

# Print DataFrame
master_movie_df
# Out:
#                     Movie Name  IMDB Rating  Rotten Tomatoes Rating  \
# 0                        Focus           66                      56
# 1            Termintor Genisys           64                      26
# 2                          Pan           57                      27
# 3                        Ted 2           63                      45
# 4                   Inside Out           82                      98
# 5                   Goosebumps           63                      78
# 6                        Aloha           54                      20
# 7                   Cinderella           69                      85
# 8                    Self/less           65                      19
# 9                     Ip Man 3           71                      78
# 10                    13 Hours           73                      51
# 11                Ghostbusters           78                      97
# 12  My Big Fat Greek Wedding 2           60                      28
# 13               Gods of Egypt           54                      16
# 14             Eddie the Eagle           74                      82
# 15            Star Trek Beyond           71                      86
# 16           London Has Fallen           59                      26
# 17                The 5th Wave           52                      15
# 18               Suicide Squad           60                      27
# 19               Me Before You           74                      55
#
#     Metacritic Rating  Facebook Likes
# 0                  56           23000
# 1                  38           82000
# 2                  36           24000
# 3                  48           30000
# 4                  94          118000
# 5                  60           35000
# 6                  40           11000
# 7                  67           56000
# 8                  34           11000
# 9                  57           12000
# 10                 48           44000
# 11                 71           62000
# 12                 37           19000
# 13                 25           24000
# 14                 54           15000
# 15                 68           30000
# 16                 28           28000
# 17                 33           14000
# 18                 40           80000
# 19                 51           51000
